# %% [markdown]
# # EDA y modelado inicial
# Notebook guía para cargar datos, revisar la variable objetivo y entrenar modelos desde `src/train_models.py`.

# %%
from src.data_loader import load_dataset
from src.preprocessing import prepare_model_data
df = load_dataset()
X, y, processed, features = prepare_model_data(df)
processed.head()

# %%
y.value_counts(normalize=True)

# %%
# Para ejecutar el pipeline completo:
# !python src/train_models.py
